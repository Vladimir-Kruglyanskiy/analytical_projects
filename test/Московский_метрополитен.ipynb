# %% [markdown]
# #Анализ нарушений московского метрополитена.

# %% [markdown]
# Задачи:
# * Загрузить данные и познакомиться с ними;
# * Предобработка данных и предварительное исследование;
# * Исследовательский анализ;
# * Формулировка выводов.

# %% [markdown]
# ##1) Знакомство с датасетом

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/metro.xlsx')

# %%
df.head()
# Out:
#         Начало случая    Окончание случая  Перерыв в движении, мин  \
# 0 1974-01-01 00:00:00 2022-01-01 00:01:00                        0
# 1 1974-01-01 00:01:00 2022-01-01 00:03:00                        0
# 2 1974-01-01 00:06:00 2022-01-01 00:08:00                        0
# 3 1974-01-01 00:11:00 2022-01-01 00:13:00                        0
# 4 1974-01-01 00:13:00 2022-01-01 00:15:00                        0
#
#    id станции Станционный путь Перегон  Кол-во опоздавших поездов  \
# 0        83.0              NaN     NaN                          0
# 1        87.0              NaN     NaN                          0
# 2        49.0              NaN     NaN                          0
# 3       274.0              NaN     NaN                          0
# 4        81.0              NaN     NaN                          0
#
#    Кол-во минут опоздания  Кол-во полных отмен  Кол-во участковых отмен  \
# 0                       0                    0                        0
# 1                       0                    0                        0
# 2                       0                    0                        0
# 3                       0                    0                        0
# 4                       0                    0                        0
#
#    Кол-во внеплановых высадок пассажиров                       Линия  \
# 0                                      0                   Кольцевая
# 1                                      0                   Кольцевая
# 2                                      0                   Бутовская
# 3                                      0  Таганско-краснопресненская
# 4                                      0                   Кольцевая
#
#   Ответственная служба                                      Тип нарушения  \
# 0                   ЭС  Остановка эскалатора из-за нарушения правил по...
# 1                   ЭС       Остановка эскалатора ручкой СТОП пассажирами
# 2                   ЭС  Остановка эскалатора ручкой СТОП из-за угрозы ...
# 3                   ЭС  Остановка эскалатора ручкой СТОП из-за угрозы ...
# 4                   ЭС          Падение пассажира на эскалаторе без травм
#
#                                Причины возникновения Наименование устройства  \
# 0  Остановка эскалатора из-за нарушения правил по...               Эскалатор
# 1       Остановка эскалатора ручкой СТОП пассажирами               Эскалатор
# 2  Остановка эскалатора ручкой СТОП из-за угрозы ...               Эскалатор
# 3  Остановка эскалатора ручкой СТОП из-за угрозы ...               Эскалатор
# 4          Падение пассажира на эскалаторе без травм               Эскалатор
#
#   Наименование детали устройства Общая причина возникновения
# 0                            NaN         Действия пассажиров
# 1                            NaN         Действия пассажиров
# 2                            NaN         Действия пассажиров
# 3                            NaN         Действия пассажиров
# 4                Огибной участок         Действия пассажиров

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.head()
# Out:
#         начало_случая    окончание_случая  перерыв_в_движении,_мин  \
# 0 1974-01-01 00:00:00 2022-01-01 00:01:00                        0
# 1 1974-01-01 00:01:00 2022-01-01 00:03:00                        0
# 2 1974-01-01 00:06:00 2022-01-01 00:08:00                        0
# 3 1974-01-01 00:11:00 2022-01-01 00:13:00                        0
# 4 1974-01-01 00:13:00 2022-01-01 00:15:00                        0
#
#    id_станции станционный_путь перегон  кол-во_опоздавших_поездов  \
# 0        83.0              NaN     NaN                          0
# 1        87.0              NaN     NaN                          0
# 2        49.0              NaN     NaN                          0
# 3       274.0              NaN     NaN                          0
# 4        81.0              NaN     NaN                          0
#
#    кол-во_минут_опоздания  кол-во_полных_отмен  кол-во_участковых_отмен  \
# 0                       0                    0                        0
# 1                       0                    0                        0
# 2                       0                    0                        0
# 3                       0                    0                        0
# 4                       0                    0                        0
#
#    кол-во_внеплановых_высадок_пассажиров                       линия  \
# 0                                      0                   Кольцевая
# 1                                      0                   Кольцевая
# 2                                      0                   Бутовская
# 3                                      0  Таганско-краснопресненская
# 4                                      0                   Кольцевая
#
#   ответственная_служба                                      тип_нарушения  \
# 0                   ЭС  Остановка эскалатора из-за нарушения правил по...
# 1                   ЭС       Остановка эскалатора ручкой СТОП пассажирами
# 2                   ЭС  Остановка эскалатора ручкой СТОП из-за угрозы ...
# 3                   ЭС  Остановка эскалатора ручкой СТОП из-за угрозы ...
# 4                   ЭС          Падение пассажира на эскалаторе без травм
#
#                                причины_возникновения наименование_устройства  \
# 0  Остановка эскалатора из-за нарушения правил по...               Эскалатор
# 1       Остановка эскалатора ручкой СТОП пассажирами               Эскалатор
# 2  Остановка эскалатора ручкой СТОП из-за угрозы ...               Эскалатор
# 3  Остановка эскалатора ручкой СТОП из-за угрозы ...               Эскалатор
# 4          Падение пассажира на эскалаторе без травм               Эскалатор
#
#   наименование_детали_устройства общая_причина_возникновения
# 0                            NaN         Действия пассажиров
# 1                            NaN         Действия пассажиров
# 2                            NaN         Действия пассажиров
# 3                            NaN         Действия пассажиров
# 4                Огибной участок         Действия пассажиров
